# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('dataset/Tweets.csv')

# %%
data.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
data = data[['airline_sentiment','text']] #只需要评价类型与评价内容

# %%
data.head() #可以去掉中性评价
# Out:
#   airline_sentiment                                               text
# 0           neutral                @VirginAmerica What @dhepburn said.
# 1          positive  @VirginAmerica plus you've added commercials t...
# 2           neutral  @VirginAmerica I didn't today... Must mean I n...
# 3          negative  @VirginAmerica it's really aggressive to blast...
# 4          negative  @VirginAmerica and it's a really big bad thing...

# %%
data.airline_sentiment.unique()
# Out:
# array(['neutral', 'positive', 'negative'], dtype=object)

# %%
data.airline_sentiment.value_counts()
# Out:
# negative    9178
# neutral     3099
# positive    2363
# Name: airline_sentiment, dtype: int64

# %%
#提取思路 negative 与positive相同数量

# %%
data_p = data[data.airline_sentiment == 'positive']

# %%
data_n = data[data.airline_sentiment == 'negative']

# %%
data_n = data_n.iloc[:len(data_p)]

# %%
len(data_n),len(data_p)
# Out:
# (2363, 2363)

# %%
data = pd.concat([data_n, data_p])

# %%
data
# Out:
#       airline_sentiment                                               text
# 3              negative  @VirginAmerica it's really aggressive to blast...
# 4              negative  @VirginAmerica and it's a really big bad thing...
# 5              negative  @VirginAmerica seriously would pay $30 a fligh...
# 15             negative      @VirginAmerica SFO-PDX schedule is still MIA.
# 17             negative  @VirginAmerica  I flew from NYC to SFO last we...
# ...                 ...                                                ...
# 14623          positive  @AmericanAir Love the new planes for the JFK-L...
# 14625          positive  @AmericanAir Flight 236 was great. Fantastic c...
# 14628          positive  Thank you. “@AmericanAir: @jlhalldc Customer R...
# 14630          positive                        @AmericanAir Thanks! He is.
# 14635          positive  @AmericanAir thank you we got on a different f...
#
# [4726 rows x 2 columns]

# %%
data = data.sample(len(data)) #通过取值来乱序

# %%
data
# Out:
#       airline_sentiment                                               text
# 8420           positive  @JetBlue OH YEAH!!! great flight down to Mexic...
# 1199           negative  @united JH, thanks so much for reaching out. I...
# 7434           positive          @JetBlue oh. And thank you for responding
# 2328           negative  @united call wait times are over 20 minutes an...
# 833            positive  @united Made the upgrade list. Will fly 1st to...
# ...                 ...                                                ...
# 2903           negative  @united I get that. But doing it by giving ina...
# 7294           positive                                   @JetBlue awesome
# 7731           positive                                @JetBlue thank you!
# 741            negative  @united The agent that met us at the gate said...
# 10835          positive  @USAirways i got through and am able to switch...
#
# [4726 rows x 2 columns]

# %%
data['review'] = (data.airline_sentiment == 'positive').astype('int')

# %%
del data['airline_sentiment']

# %% [markdown]
# tf.keras.layers.Embedding #把文本向量化

# %%
import re

# %%
token = re.compile('[A-Za-z]+ | [!?,.()]') #只要这些符号

# %%
def reg_text(text):
    new_text = token.findall(text) 
    new_text = [word.lower() for word in new_text] #全部变为小写
    return new_text

# %%
data['text'] = data.text.apply(reg_text)

# %%
data
# Out:
#                                                     text  review
# 8420   [jetblue , oh , great , flight , down , to , m...       1
# 1199   [united , thanks , so , much , for , reaching ...       0
# 7434                [jetblue , and , thank , you , for ]       1
# 2328   [united , call , wait , times , are , over , m...       0
# 833    [united , made , the , upgrade , will , fly , ...       1
# ...                                                  ...     ...
# 2903   [united , i , get , but , doing , it , by , gi...       0
# 7294                                          [jetblue ]       1
# 7731                                  [jetblue , thank ]       1
# 741    [united , the , agent , that , met , us , at ,...       0
# 10835  [usairways , i , got , through , and , am , ab...       1
#
# [4726 rows x 2 columns]

# %%
#将英文单词变成整数

# %%
word_set = set() #set会把重复值去掉
for text in data.text:
    for word in text:
        word_set.add(word)

# %%
max_word = len(word_set) + 1
max_word
# Out:
# 5323

# %%
word_list = list(word_set)

# %%
word_index = dict((word, word_list.index(word)+1) for word in word_list)

# %%
word_index
# Out:
# {'choosing ': 1,
#  'group ': 2,
#  'custs ': 3,
#  'alison ': 4,
#  'resolution ': 5,
#  'screensand ': 6,
#  'giants ': 7,
#  'problem ': 8,
#  'departure ': 9,
#  'please ': 10,
#  'virginatlantic ': 11,
#  'pre ': 12,
#  'hostage ': 13,
#  'costing ': 14,
#  'conf ': 15,
#  'copy ': 16,
#  'transatlantic ': 17,
#  'access ': 18,
#  'members ': 19,
#  'best ': 20,
#  'daydreaming ': 21,
#  'exception ': 22,
#  'aboard ': 23,
#  'faint ': 24,
#  'formed ': 25,
#  'anna ': 26,
#  'thecandacesmith ': 27,
#  'govt ': 28,
#  'provided ': 29,
#  'streamline ': 30,
#  'lame ': 31,
#  'thks ': 32,
#  'move ': 33,
#  'vs ': 34,
#  'condo ': 35,
#  'wht ': 36,
#  'baseball ': 37,
#  'junction ': 38,
#  'columbus ': 39,
#  'lowered ': 40,
#  'tuned ': 41,
#  'memory ': 42,
#  'kiosk ': 43,
#  'personally ': 44,
#  'appropriate ': 45,
#  'child ': 46,
#  'following ': 47,
#  'jmercadomma ': 48,
#  'fare ': 49,
#  'agree ': 50,
#  'sent ': 51,
#  'knew ': 52,
#  'qc ': 53,
#  'rosetta ': 54,
#  'lovejetblue ': 55,
#  'airport ': 56,
#  'pray ': 57,
#  'painless ': 58,
#  'led ': 59,
#  'evening ': 60,
#  'build ': 61,
#  'apparently ': 62,
#  'encouraged ': 63,
#  'okay ': 64,
#  'sock ': 65,
#  'amount ': 66,
#  'sunrise ': 67,
#  'sorry ': 68,
#  'web ': 69,
#  'met ': 70,
#  'rigorous ': 71,
#  'logan ': 72,
#  'routes ': 73,
#  'disinfectant ': 74,
#  'contacted ': 75,
#  'concert ': 76,
#  'cmh ': 77,
#  'full ': 78,
#  'hook ': 79,
#  'luck ': 80,
#  'wait ': 81,
#  'aaron ': 82,
#  'flipping ': 83,
#  'packages ': 84,
#  'dontchangeathing ': 85,
#  'strongly ': 86,
#  'phlairport ': 87,
#  'gladys ': 88,
#  'albanyairport ': 89,
#  'unusable ': 90,
#  'space ': 91,
#  'actions ': 92,
#  'queues ': 93,
#  'power ': 94,
#  'touched ': 95,
#  'accountable ': 96,
#  'blatant ': 97,
#  'mite ': 98,
#  'complimentary ': 99,
#  'keeping ': 100,
#  'guests ': 101,
#  'mci ': 102,
#  'published ': 103,
#  'overflight ': 104,
#  'hofmann ': 105,
#  'mentions ': 106,
#  'basically ': 107,
#  'mosaicmecrazy ': 108,
#  'crying ': 109,
#  'shv ': 110,
#  'card ': 111,
#  'husband ': 112,
#  'hdn ': 113,
#  'now ': 114,
#  'hotl ': 115,
#  'joking ': 116,
#  'caned ': 117,
#  'cooker ': 118,
#  'disney ': 119,
#  'map ': 120,
#  'lovely ': 121,
#  'ugfnm ': 122,
#  'whatstheholdup ': 123,
#  'madrid ': 124,
#  'sibling ': 125,
#  'contain ': 126,
#  'non ': 127,
#  'inconvenience ': 128,
#  'advising ': 129,
#  'thanx ': 130,
#  'backhome ': 131,
#  'outsourced ': 132,
#  'iced ': 133,
#  'items ': 134,
#  'remind ': 135,
#  'alerted ': 136,
#  'damages ': 137,
#  'italy ': 138,
#  'sittin ': 139,
#  'kinda ': 140,
#  'newplanesmell ': 141,
#  'simply ': 142,
#  'bked ': 143,
#  'leanin ': 144,
#  'travelling ': 145,
#  'rd ': 146,
#  'jetbluesofly ': 147,
#  'rick ': 148,
#  'seating ': 149,
#  'sole ': 150,
#  'equals ': 151,
#  'switch ': 152,
#  'county ': 153,
#  'rt ': 154,
#  'act ': 155,
#  'pqd ': 156,
#  'convo ': 157,
#  'so ': 158,
#  'representative ': 159,
#  'pilot ': 160,
#  'guarantee ': 161,
#  'preggo ': 162,
#  'these ': 163,
#  'unnecessary ': 164,
#  'wheels ': 165,
#  'dadboner ': 166,
#  'belong ': 167,
#  'jana ': 168,
#  'damper ': 169,
#  'shits ': 170,
#  'favorite ': 171,
#  'could ': 172,
#  'safely ': 173,
#  'jan ': 174,
#  'cloud ': 175,
#  'indication ': 176,
#  'everything ': 177,
#  'concerned ': 178,
#  'saharasams ': 179,
#  'popular ': 180,
#  'noneother ': 181,
#  'slow ': 182,
#  'dorm ': 183,
#  'reserv ': 184,
#  'earn ': 185,
#  'returning ': 186,
#  'coast ': 187,
#  'split ': 188,
#  'treat ': 189,
#  'clean ': 190,
#  'luv ': 191,
#  'raised ': 192,
#  'age ': 193,
#  'yasss ': 194,
#  'iflyalot ': 195,
#  'check ': 196,
#  'unbelievable ': 197,
#  'zrh ': 198,
#  'coupon ': 199,
#  'roundtrip ': 200,
#  'reputation ': 201,
#  'gift ': 202,
#  'befor ': 203,
#  'pushed ': 204,
#  'anticipate ': 205,
#  'hr ': 206,
#  'refundprocedurenottoopainful ': 207,
#  'west ': 208,
#  'reclaim ': 209,
#  'boss ': 210,
#  'america ': 211,
#  'diego ': 212,
#  'detail ': 213,
#  'americanairlines ': 214,
#  'unfriendlyskies ': 215,
#  'reach ': 216,
#  'whats ': 217,
#  'international ': 218,
#  'icu ': 219,
#  'arvls ': 220,
#  'reviewed ': 221,
#  'manilla ': 222,
#  'dfw ': 223,
#  'feces ': 224,
#  'neighboring ': 225,
#  'belligerent ': 226,
#  'fits ': 227,
#  'poor ': 228,
#  'rows ': 229,
#  'proper ': 230,
#  'lastflightofthenight ': 231,
#  'allergies ': 232,
#  'pull ': 233,
#  'short ': 234,
#  'head ': 235,
#  'peeps ': 236,
#  'obviously ': 237,
#  'bags ': 238,
#  'leinenkugels ': 239,
#  'laguardia ': 240,
#  'unaccounted ': 241,
#  'describe ': 242,
#  'tremendous ': 243,
#  'transfers ': 244,
#  'blatantly ': 245,
#  'professional ': 246,
#  'journey ': 247,
#  'stow ': 248,
#  'stand ': 249,
#  'noticing ': 250,
#  'tiffany ': 251,
#  'atx ': 252,
#  'fyvrfn ': 253,
#  'stat ': 254,
#  'shocking ': 255,
#  'jacked ': 256,
#  'coles ': 257,
#  'partner ': 258,
#  'beanie ': 259,
#  'closet ': 260,
#  'term ': 261,
#  'flights ': 262,
#  'shaker ': 263,
#  'displaced ': 264,
#  'missedwork ': 265,
#  'reinstated ': 266,
#  'unless ': 267,
#  'delinquent ': 268,
#  'avis ': 269,
#  'aircrft ': 270,
#  'inquiry ': 271,
#  'if ': 272,
#  'lay ': 273,
#  'ignoring ': 274,
#  'tagged ': 275,
#  'ithica ': 276,
#  'damage ': 277,
#  'ruining ': 278,
#  'previous ': 279,
#  'cover ': 280,
#  'bins ': 281,
#  'understanding ': 282,
#  'th ': 283,
#  'furious ': 284,
#  'flt ': 285,
#  'css ': 286,
#  'ft ': 287,
#  'therefore ': 288,
#  'logistics ': 289,
#  'mae ': 290,
#  'tweeting ': 291,
#  'santa ': 292,
#  'icloud ': 293,
#  'pamgrout ': 294,
#  'mom ': 295,
#  'playing ': 296,
#  'rated ': 297,
#  'loft ': 298,
#  'lifeline ': 299,
#  'bonus ': 300,
#  'spent ': 301,
#  'forgetting ': 302,
#  'that ': 303,
#  'honest ': 304,
#  'siouxfalls ': 305,
#  'logs ': 306,
#  'win ': 307,
#  'indeed ': 308,
#  'pick ': 309,
#  'waiting ': 310,
#  'spelling ': 311,
#  'drinks ': 312,
#  'mark ': 313,
#  'affiliate ': 314,
#  'registered ': 315,
#  'rechecked ': 316,
#  'jdbwaffles ': 317,
#  'order ': 318,
#  'dream ': 319,
#  'uk ': 320,
#  'appointed ': 321,
#  'kat ': 322,
#  'suggested ': 323,
#  'amarillo ': 324,
#  'compare ': 325,
#  'crash ': 326,
#  'filed ': 327,
#  'sjc ': 328,
#  'flipped ': 329,
#  'goal ': 330,
#  'fails ': 331,
#  'lightning ': 332,
#  'delays ': 333,
#  'hilo ': 334,
#  'joanna ': 335,
#  'ndary ': 336,
#  'spread ': 337,
#  'greeting ': 338,
#  'permissions ': 339,
#  'realized ': 340,
#  'handedly ': 341,
#  'indy ': 342,
#  'disgusted ': 343,
#  'kleankanteen ': 344,
#  'get ': 345,
#  'prison ': 346,
#  'wasnt ': 347,
#  'years ': 348,
#  'whereabouts ': 349,
#  'supply ': 350,
#  'transcontinental ': 351,
#  'maintenece ': 352,
#  'embody ': 353,
#  'competent ': 354,
#  'timezones ': 355,
#  'before ': 356,
#  'abq ': 357,
#  'invoice ': 358,
#  'vx ': 359,
#  'barbara ': 360,
#  'pgashow ': 361,
#  'indicates ': 362,
#  'annoying ': 363,
#  'moves ': 364,
#  'rich ': 365,
#  'ripped ': 366,
#  'question ': 367,
#  'fine ': 368,
#  'solving ': 369,
#  'annual ': 370,
#  'approve ': 371,
#  'currently ': 372,
#  'advertised ': 373,
#  'unplanned ': 374,
#  'sundays ': 375,
#  'serving ': 376,
#  'status ': 377,
#  'months ': 378,
#  'headed ': 379,
#  'thing ': 380,
#  'ahead ': 381,
#  'phx ': 382,
#  'tattoo ': 383,
#  'parryaftab ': 384,
#  'daysofunitedfailures ': 385,
#  'mpagent ': 386,
#  'ward ': 387,
#  'guam ': 388,
#  'official ': 389,
#  'praying ': 390,
#  'wed ': 391,
#  'computers ': 392,
#  'hrs ': 393,
#  'poorservice ': 394,
#  'same ': 395,
#  'makingthingseasy ': 396,
#  'model ': 397,
#  'ferrissalameh ': 398,
#  'remote ': 399,
#  'hospitality ': 400,
#  'deplaned ': 401,
#  'counter ': 402,
#  'many ': 403,
#  'comedy ': 404,
#  'lolol ': 405,
#  'useless ': 406,
#  'cle ': 407,
#  'mileage ': 408,
#  'lindsey ': 409,
#  'images ': 410,
#  'pic ': 411,
#  'southwestluv ': 412,
#  'stressors ': 413,
#  'yep ': 414,
#  'misinformation ': 415,
#  'stclass ': 416,
#  'helping ': 417,
#  'committed ': 418,
#  'typical ': 419,
#  'embarrassing ': 420,
#  'films ': 421,
#  'disappeared ': 422,
#  'staralliance ': 423,
#  'yet ': 424,
#  'log ': 425,
#  'informed ': 426,
#  'southwestsmoothie ': 427,
#  'peopleon ': 428,
#  'nustgpelsf ': 429,
#  'pet ': 430,
#  'london ': 431,
#  'carriers ': 432,
#  'heard ': 433,
#  'orlando ': 434,
#  'bestinclass ': 435,
#  'behaves ': 436,
#  'expand ': 437,
#  'screening ': 438,
#  'incubator ': 439,
#  'decline ': 440,
#  'focused ': 441,
#  'snack ': 442,
#  'usd ': 443,
#  'discount ': 444,
#  'maintained ': 445,
#  'exchange ': 446,
#  'walk ': 447,
#  'landed ': 448,
#  'people ': 449,
#  'accommodations ': 450,
#  'atl ': 451,
#  'regarding ': 452,
#  'nah ': 453,
#  'opaque ': 454,
#  'hardly ': 455,
#  'slots ': 456,
#  'bottom ': 457,
#  'orangecounty ': 458,
#  'congratulations ': 459,
#  'unsmiling ': 460,
#  'pretend ': 461,
#  'betty ': 462,
#  'spaces ': 463,
#  'ways ': 464,
#  'amateurs ': 465,
#  'musicians ': 466,
#  'nippon ': 467,
#  'fax ': 468,
#  'lol ': 469,
#  'geiger ': 470,
#  'chicago ': 471,
#  'expires ': 472,
#  'puj ': 473,
#  'sooner ': 474,
#  'carrieunderwood ': 475,
#  'successful ': 476,
#  'kidnapped ': 477,
#  'nope ': 478,
#  'sna ': 479,
#  'ensuring ': 480,
#  'language ': 481,
#  'passbook ': 482,
#  'cust ': 483,
#  'police ': 484,
#  'handling ': 485,
#  'pleasantly ': 486,
#  'flightattendant ': 487,
#  'beating ': 488,
#  'efficiency ': 489,
#  'turbulence ': 490,
#  'netneutrality ': 491,
#  'dislike ': 492,
#  'little ': 493,
#  'promised ': 494,
#  'reference ': 495,
#  'mr ': 496,
#  'hanging ': 497,
#  'portion ': 498,
#  'partnered ': 499,
#  'puts ': 500,
#  'mental ': 501,
#  'jua ': 502,
#  'intuitlife ': 503,
#  'satisfied ': 504,
#  'instagram ': 505,
#  'booted ': 506,
#  'various ': 507,
#  'phn ': 508,
#  'appreciation ': 509,
#  'celebrating ': 510,
#  'tandoori ': 511,
#  'remotely ': 512,
#  'credit ': 513,
#  'stayed ': 514,
#  'bucks ': 515,
#  'qcxk ': 516,
#  'purely ': 517,
#  'released ': 518,
#  'sucking ': 519,
#  'cnxn ': 520,
#  'elevate ': 521,
#  'cc ': 522,
#  'solve ': 523,
#  'designated ': 524,
#  'coach ': 525,
#  'followed ': 526,
#  'switching ': 527,
#  'ssal ': 528,
#  'plans ': 529,
#  'present ': 530,
#  'occurs ': 531,
#  'the ': 532,
#  'recording ': 533,
#  'capabilities ': 534,
#  'earphone ': 535,
#  'bless ': 536,
#  'relationship ': 537,
#  'suuuuper ': 538,
#  'beverages ': 539,
#  'sunglasses ': 540,
#  'usairway ': 541,
#  'telling ': 542,
#  'avalible ': 543,
#  'mess ': 544,
#  'seriously ': 545,
#  'easier ': 546,
#  'adve ': 547,
#  'worker ': 548,
#  'lloyd ': 549,
#  'curious ': 550,
#  'lisa ': 551,
#  'westagard ': 552,
#  'small ': 553,
#  'chips ': 554,
#  'honeymoon ': 555,
#  'monitoring ': 556,
#  'accompaniments ': 557,
#  'rental ': 558,
#  'aspenbaggagefail ': 559,
#  'club ': 560,
#  'badservice ': 561,
#  'gso ': 562,
#  'disappointing ': 563,
#  'engagement ': 564,
#  'proportion ': 565,
#  'delete ': 566,
#  'unscheduled ': 567,
#  'mgr ': 568,
#  'grounded ': 569,
#  'were ': 570,
#  'filling ': 571,
#  'jacqueline ': 572,
#  'y ': 573,
#  'weighed ': 574,
#  'swivel ': 575,
#  'outside ': 576,
#  'rapidly ': 577,
#  'skiplagged ': 578,
#  'acts ': 579,
#  'sato ': 580,
#  'trains ': 581,
#  'rollerboards ': 582,
#  'cookies ': 583,
#  'tech ': 584,
#  'unpleased ': 585,
#  'update ': 586,
#  'airways ': 587,
#  'for ': 588,
#  'headphones ': 589,
#  'runway ': 590,
#  'reroute ': 591,
#  'instructed ': 592,
#  'secure ': 593,
#  'belt ': 594,
#  'carryon ': 595,
#  'announcement ': 596,
#  'senior ': 597,
#  'causing ': 598,
#  'auciello ': 599,
#  'similar ': 600,
#  'operations ': 601,
#  'disaster ': 602,
#  'private ': 603,
#  'retook ': 604,
#  'waitingonapilot ': 605,
#  'actively ': 606,
#  'enhance ': 607,
#  'preventative ': 608,
#  'charleston ': 609,
#  'who ': 610,
#  'music ': 611,
#  'michele ': 612,
#  'it ': 613,
#  'joni ': 614,
#  'reunited ': 615,
#  'fares ': 616,
#  'several ': 617,
#  'statement ': 618,
#  'arizona ': 619,
#  'sports ': 620,
#  'consistent ': 621,
#  'arrogant ': 622,
#  'filled ': 623,
#  'crashed ': 624,
#  'props ': 625,
#  'nit ': 626,
#  'desperately ': 627,
#  'raleigh ': 628,
#  'caring ': 629,
#  'karma ': 630,
#  'horrendous ': 631,
#  'laugh ': 632,
#  'sprinting ': 633,
#  'beat ': 634,
#  'named ': 635,
#  'work ': 636,
#  'mouse ': 637,
#  'robotweeting ': 638,
#  'dont ': 639,
#  'courier ': 640,
#  'not ': 641,
#  'freecomedyshow ': 642,
#  'curbside ': 643,
#  'blog ': 644,
#  'booked ': 645,
#  'huge ': 646,
#  'lowest ': 647,
#  'fill ': 648,
#  'ambassador ': 649,
#  'box ': 650,
#  'was ': 651,
#  'by ': 652,
#  'brain ': 653,
#  'impress ': 654,
#  'form ': 655,
#  'last ': 656,
#  'howisthatpossible ': 657,
#  'received ': 658,
#  'mllovelace ': 659,
#  'bestfriends ': 660,
#  'believe ': 661,
#  'karen ': 662,
#  'disability ': 663,
#  'asking ': 664,
#  'sleeping ': 665,
#  'resent ': 666,
#  'schedule ': 667,
#  'guardia ': 668,
#  'cking ': 669,
#  'robertdwyer ': 670,
#  'maintenance ': 671,
#  'skin ': 672,
#  'lousy ': 673,
#  'storm ': 674,
#  'mike ': 675,
#  'hunt ': 676,
#  'throwback ': 677,
#  'cruise ': 678,
#  'lungs ': 679,
#  'truly ': 680,
#  'esp ': 681,
#  'fantasy ': 682,
#  'revisiting ': 683,
#  'intuit ': 684,
#  'told ': 685,
#  'reasonable ': 686,
#  'coworkers ': 687,
#  'm ': 688,
#  'bots ': 689,
#  'married ': 690,
#  'today ': 691,
#  'file ': 692,
#  'false ': 693,
#  'goodness ': 694,
#  'ear ': 695,
#  'wants ': 696,
#  'decided ': 697,
#  'caribbean ': 698,
#  'guy ': 699,
#  'itslaloca ': 700,
#  'its ': 701,
#  'true ': 702,
#  'freddie ': 703,
#  'disunited ': 704,
#  'voted ': 705,
#  'challenging ': 706,
#  'wheelsup ': 707,
#  'synonymous ': 708,
#  'all ': 709,
#  'turn ': 710,
#  'replacement ': 711,
#  'represent ': 712,
#  'standbye ': 713,
#  'voucher ': 714,
#  'open ': 715,
#  'l ': 716,
#  'jersey ': 717,
#  'shaking ': 718,
#  'matter ': 719,
#  'falling ': 720,
#  'logout ': 721,
#  'distress ': 722,
#  'reebok ': 723,
#  'etihad ': 724,
#  'ones ': 725,
#  'friends ': 726,
#  'mostly ': 727,
#  'temps ': 728,
#  'florida ': 729,
#  'mountains ': 730,
#  'jh ': 731,
#  'effort ': 732,
#  'hartford ': 733,
#  'rocked ': 734,
#  'aviv ': 735,
#  'cuz ': 736,
#  'bae ': 737,
#  'calling ': 738,
#  'newest ': 739,
#  'suit ': 740,
#  'announce ': 741,
#  'rainy ': 742,
#  'entrees ': 743,
#  'loving ': 744,
#  'frozen ': 745,
#  'strives ': 746,
#  'none ': 747,
#  'cockpit ': 748,
#  'ridiculousness ': 749,
#  'between ': 750,
#  'u ': 751,
#  'boiled ': 752,
#  'oscars ': 753,
#  'promo ': 754,
#  'join ': 755,
#  'you ': 756,
#  'adore ': 757,
#  'bothered ': 758,
#  'highbuddyyy ': 759,
#  'gma ': 760,
#  'but ': 761,
#  'thanked ': 762,
#  'kathrynsotelo ': 763,
#  'enforce ': 764,
#  'into ': 765,
#  'unrivalled ': 766,
#  'hashtag ': 767,
#  'hold ': 768,
#  'tried ': 769,
#  'coats ': 770,
#  'slide ': 771,
#  'hotspot ': 772,
#  'cs ': 773,
#  'minor ': 774,
#  'catsanddogslivingtogether ': 775,
#  'picked ': 776,
#  'transfer ': 777,
#  'strangers ': 778,
#  'assistance ': 779,
#  'enuf ': 780,
#  'train ': 781,
#  'shows ': 782,
#  'notified ': 783,
#  'charles ': 784,
#  'input ': 785,
#  'shin ': 786,
#  'xfinity ': 787,
#  'segway ': 788,
#  'class ': 789,
#  'button ': 790,
#  'anthony ': 791,
#  'duty ': 792,
#  'suitcase ': 793,
#  'simplify ': 794,
#  'runs ': 795,
#  'misses ': 796,
#  'know ': 797,
#  'updates ': 798,
#  'wife ': 799,
#  'rolling ': 800,
#  'traveler ': 801,
#  'ticked ': 802,
#  'reschedule ': 803,
#  'operation ': 804,
#  'ny ': 805,
#  'fat ': 806,
#  'placed ': 807,
#  'v ': 808,
#  'wasted ': 809,
#  'yelling ': 810,
#  'course ': 811,
#  'staff ': 812,
#  'hemispheresmag ': 813,
#  'useful ': 814,
#  'partial ': 815,
#  'interesting ': 816,
#  'rudest ': 817,
#  'method ': 818,
#  'shameful ': 819,
#  'exclusively ': 820,
#  'notifications ': 821,
#  'com ': 822,
#  'promises ': 823,
#  'clue ': 824,
#  'unpredictable ': 825,
#  'bearable ': 826,
#  'amazed ': 827,
#  'swa ': 828,
#  'pqm ': 829,
#  'badcustomerservice ': 830,
#  'sweetheart ': 831,
#  'herman ': 832,
#  'cluster ': 833,
#  'luggages ': 834,
#  'shouldnt ': 835,
#  'destinationdragons ': 836,
#  'username ': 837,
#  'ive ': 838,
#  'miss ': 839,
#  'fan ': 840,
#  'often ': 841,
#  'either ': 842,
#  'jenniferwalshpr ': 843,
#  'break ': 844,
#  'honored ': 845,
#  'payton ': 846,
#  'yours ': 847,
#  'mke ': 848,
#  'piggy ': 849,
#  'tomorrow ': 850,
#  'design ': 851,
#  'bso ': 852,
#  'johnwayneair ': 853,
#  'traditions ': 854,
#  'reply ': 855,
#  'closed ': 856,
#  'diverted ': 857,
#  'londonfashionweek ': 858,
#  'avgeek ': 859,
#  'incredible ': 860,
#  'router ': 861,
#  'wonderful ': 862,
#  'owe ': 863,
#  'with ': 864,
#  'proud ': 865,
#  'guitar ': 866,
#  'disruption ': 867,
#  'intentional ': 868,
#  'monitor ': 869,
#  'natca ': 870,
#  'miamore ': 871,
#  'especially ': 872,
#  'thats ': 873,
#  'completely ': 874,
#  't ': 875,
#  'suppose ': 876,
#  'ojrsdwpkk ': 877,
#  'flattering ': 878,
#  'executive ': 879,
#  'australia ': 880,
#  'myrtle ': 881,
#  'shut ': 882,
#  'goingforgreat ': 883,
#  'blown ': 884,
#  'showexpert ': 885,
#  'an ': 886,
#  'jam ': 887,
#  'sedholm ': 888,
#  'solution ': 889,
#  'rachelle ': 890,
#  'sooooooo ': 891,
#  'dry ': 892,
#  'mco ': 893,
#  'swadiversity ': 894,
#  'measured ': 895,
#  'hawaii ': 896,
#  'instant ': 897,
#  'ilm ': 898,
#  'putting ': 899,
#  'catching ': 900,
#  'procedures ': 901,
#  'latrice ': 902,
#  'barrel ': 903,
#  'napkins ': 904,
#  'tries ': 905,
#  'thinner ': 906,
#  'subsequent ': 907,
#  'pssgrs ': 908,
#  'hire ': 909,
#  'prefer ': 910,
#  'fab ': 911,
#  'reminds ': 912,
#  'portlandjetport ': 913,
#  'firstclass ': 914,
#  'constant ': 915,
#  'cramped ': 916,
#  'yes ': 917,
#  'hectic ': 918,
#  'hardworking ': 919,
#  'dragons ': 920,
#  'listed ': 921,
#  'additional ': 922,
#  'excellence ': 923,
#  'fib ': 924,
#  'see ': 925,
#  'fedup ': 926,
#  'umosaicmecrazy ': 927,
#  'starts ': 928,
#  'heads ': 929,
#  'thete ': 930,
#  'comfort ': 931,
#  'assist ': 932,
#  'sched ': 933,
#  'canadaair ': 934,
#  'partly ': 935,
#  'austin ': 936,
#  'battierccipuppy ': 937,
#  'she ': 938,
#  'thursday ': 939,
#  'pile ': 940,
#  'fro ': 941,
#  'theellenshow ': 942,
#  'rearrange ': 943,
#  'listening ': 944,
#  'scavenger ': 945,
#  'marks ': 946,
#  'longing ': 947,
#  'ooh ': 948,
#  'pax ': 949,
#  'accurate ': 950,
#  'total ': 951,
#  'bc ': 952,
#  'jack ': 953,
#  'report ': 954,
#  'carrier ': 955,
#  'respects ': 956,
#  'deborah ': 957,
#  'market ': 958,
#  'junk ': 959,
#  'bday ': 960,
#  'afternoon ': 961,
#  'moment ': 962,
#  'us ': 963,
#  'out ': 964,
#  'invited ': 965,
#  'sosmart ': 966,
#  'phillip ': 967,
#  'fitz ': 968,
#  'rarely ': 969,
#  'vanished ': 970,
#  'provide ': 971,
#  'bobwesson ': 972,
#  'define ': 973,
#  'hands ': 974,
#  'brandloveaffair ': 975,
#  'wanted ': 976,
#  'kind ': 977,
#  'danahajek ': 978,
#  'systemwide ': 979,
#  'treating ': 980,
#  'somewhere ': 981,
#  'hanger ': 982,
#  'guest ': 983,
#  'suspect ': 984,
#  'cross ': 985,
#  'luxclark ': 986,
#  'screens ': 987,
#  'spend ': 988,
#  'travelocity ': 989,
#  'turned ': 990,
#  'compensated ': 991,
#  'actual ': 992,
#  'milan ': 993,
#  'ct ': 994,
#  'thx ': 995,
#  'miranda ': 996,
#  'damn ': 997,
#  'bummer ': 998,
#  'text ': 999,
#  'added ': 1000,
#  ...}

# %%
data_ok = data.text.apply(lambda x:[word_index.get(word, 0) for word in x])

# %%
data_ok
# Out:
# 8420     [4004, 4114, 4078, 4790, 2309, 4583, 2131, 864...
# 1199     [4259, 4430, 158, 2130, 588, 4711, 3379, 651, ...
# 7434                          [4004, 5023, 3392, 756, 588]
# 2328     [4259, 1354, 81, 3122, 1366, 3373, 4612, 5023,...
# 833      [4259, 5025, 532, 3224, 2385, 4501, 1815, 850,...
#                                ...
# 2903     [4259, 3379, 345, 761, 3534, 613, 652, 4057, 4...
# 7294                                                [4004]
# 7731                                          [4004, 3392]
# 741      [4259, 532, 3247, 303, 70, 963, 3873, 532, 203...
# 10835    [3753, 3379, 1443, 1458, 5023, 2823, 3235, 458...
# Name: text, Length: 4726, dtype: object

# %%
len(data_ok.iloc[1])
# Out:
# 15

# %%
maxlen = max(len(x) for x in data_ok)
maxlen
# Out:
# 29

# %%
data_ok = keras.preprocessing.sequence.pad_sequences(data_ok.values, maxlen=maxlen) #将每一条评论填充到maxlen

# %%
data_ok.shape
# Out:
# (4726, 29)

# %%
data.review.values
# Out:
# array([1, 0, 1, ..., 1, 0, 1])

# %%
model = keras.Sequential() #顺序模型

# %%
#Embeding:把文本映射为一个密集向量，另一个思路：每一个字符变为独热编码

# %%
model.add(layers.Embedding(max_word, 50, input_length=maxlen))

# %%
model.add(layers.LSTM(64)) #64 包含多少个隐藏单元

# %%
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 29, 50)            266150
#
#  lstm (LSTM)                 (None, 64)                29440
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 295,655
# Trainable params: 295,655
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['acc']
)

# %%
model.fit(data_ok, data.review.values, epochs=10, batch_size=128, validation_split=0.2)#validation_split切分20%为测试数据
# Out:
# Epoch 1/10
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001F372C1D558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x000001F372C1D558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 29/30 [============================>.] - ETA: 0s - loss: 0.6504 - acc: 0.6457WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001F3731A0AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x000001F3731A0AF8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 30/30 [==============================] - 4s 57ms/step - loss: 0.6489 - acc: 0.6476 - val_loss: 0.5451 - val_acc: 0.7537
# Epoch 2/10
# 30/30 [==============================] - 1s 29ms/step - loss: 0.4192 - acc: 0.8090 - val_loss: 0.2828 - val_acc: 0.9017
# Epoch 3/10
# 30/30 [==============================] - 1s 29ms/step - loss: 0.2040 - acc: 0.9228 - val_loss: 0.2233 - val_acc: 0.9133
# Epoch 4/10
# 30/30 [==============================] - 1s 28ms/step - loss: 0.1368 - acc: 0.9521 - val_loss: 0.2094 - val_acc: 0.9144
# Epoch 5/10
# 30/30 [==============================] - 1s 30ms/step - loss: 0.1024 - acc: 0.9627 - val_loss: 0.2276 - val_acc: 0.9101
# Epoch 6/10
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0831 - acc: 0.9720 - val_loss: 0.2364 - val_acc: 0.9175
# Epoch 7/10
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0633 - acc: 0.9786 - val_loss: 0.2537 - val_acc: 0.9112
# Epoch 8/10
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0553 - acc: 0.9833 - val_loss: 0.2575 - val_acc: 0.9070
# Epoch 9/10
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0465 - acc: 0.9844 - val_loss: 0.2827 - val_acc: 0.9070
# Epoch 10/10
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0416 - acc: 0.9857 - val_loss: 0.3210 - val_acc: 0.9006
